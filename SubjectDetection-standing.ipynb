# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf

# %matplotlib inline
plt.style.use('ggplot')

# %%
def read_data(file_path):
    column_names = ['user-id','activity','timestamp', 'x-axis', 'y-axis', 'z-axis']
    data = pd.read_csv(file_path,header = None, names = column_names)
    return data

def feature_normalize(dataset):
    mu = np.mean(dataset,axis = 0)
    sigma = np.std(dataset,axis = 0)
    return (dataset - mu)/sigma

# %%
def plot_axis(ax, x, y, title):
    ax.plot(x, y)
    ax.set_title(title)
    ax.xaxis.set_visible(False)
    ax.set_ylim([min(y) - np.std(y), max(y) + np.std(y)])
    ax.set_xlim([min(x), max(x)])
    ax.grid(True)


#create
def plot_subject(subject,data):
    fig, (ax0, ax1, ax2) = plt.subplots(nrows = 3, figsize = (15, 10), sharex = True)
    plot_axis(ax0, data['timestamp'], data['x-axis'], 'x-axis')
    plot_axis(ax1, data['timestamp'], data['y-axis'], 'y-axis')
    plot_axis(ax2, data['timestamp'], data['z-axis'], 'z-axis')
    plt.subplots_adjust(hspace=0.2)
    fig.suptitle(subject)
    plt.subplots_adjust(top=0.90)
    plt.show()
    
    
def windows(data, size):
    start = 0
    while start < data.count():
        yield int(start), int(start + size)
        start += (size / 2)

def segment_signal(data,window_size = 90):
    segments = np.empty((0,window_size,3))
    labels = np.empty((0))
    for (start, end) in windows(data['timestamp'], window_size):
        x = data["x-axis"][start:end]
        y = data["y-axis"][start:end]
        z = data["z-axis"][start:end]
        if(len(dataset['timestamp'][start:end]) == window_size):
            segments = np.vstack([segments,np.dstack([x,y,z])])
            labels = np.append(labels,stats.mode(data["user-id"][start:end])[0][0])
    return segments, labels

def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev = 0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.0, shape = shape)
    return tf.Variable(initial)

def depthwise_conv2d(x, W):
    return tf.nn.depthwise_conv2d(x,W, [1, 1, 1, 1], padding='VALID')

def apply_depthwise_conv(x,kernel_size,num_channels,depth):
    weights = weight_variable([1, kernel_size, num_channels, depth])
    biases = bias_variable([depth * num_channels])
    return tf.nn.relu(tf.add(depthwise_conv2d(x, weights),biases))
    
def apply_max_pool(x,kernel_size,stride_size):
    return tf.nn.max_pool(x, ksize=[1, 1, kernel_size, 1], 
                          strides=[1, 1, stride_size, 1], padding='VALID')

# %%
dataset = read_data('/home/deepstation/PRMLlab/technicakidz/Data/actitracker_stand.txt')
#dataset = dataset.replace("\t",",",regex=True)#.replace(';',',')
dataset.shape
# Out:
# (3555, 6)

# %%
dataset[:1]
# Out:
#         user-id  activity       timestamp  x-axis  y-axis    z-axis
# 223432       27  Standing  12535892255000   -1.88    9.85 -0.231546

# %%
dataset['x-axis'] = feature_normalize(dataset['x-axis'])
dataset['y-axis'] = feature_normalize(dataset['y-axis'])
dataset['z-axis'] = feature_normalize(dataset['z-axis'])

# %%
#modify taerget(user-id)
for subject in np.unique(dataset["user-id"]):
    subset = dataset[dataset["user-id"] == subject][:40]
    plot_subject(subject,subset)

# %%
segments, labels = segment_signal(dataset)
labels = np.asarray(pd.get_dummies(labels), dtype = np.int8)
reshaped_segments = segments.reshape(len(segments), 1,90, 3)

# %%
train_test_split = np.random.rand(len(reshaped_segments)) < 0.70

train_xt = reshaped_segments[train_test_split]
train_yt = labels[train_test_split]
test_xt = reshaped_segments[~train_test_split]
test_yt = labels[~train_test_split]

# %%
#saved data
np.save('train_xt.npy',train_xt)
np.save('train_yt.npy',train_yt)
np.save('test_xt.npy',test_xt)
np.save('test_yt.npy',test_yt)

# %%
import numpy as np
train_xt = np.load('train_xt.npy')
train_yt = np.load('train_yt.npy')
test_xt = np.load('test_xt.npy')
test_yt = np.load('test_yt.npy')

# %%
#standing label
input_height = 1
input_width = 90
num_labels = 2 #number of users
num_channels = 3

batch_size = 128
kernel_size = 60
depth = 60
num_hidden = 10000

learning_rate = 1e-5
training_epochs = 2000

total_batches = train_xt.shape[0] // batch_size
X = tf.placeholder(tf.float32, shape=[None,input_height,input_width,num_channels])
Y = tf.placeholder(tf.float32, shape=[None,num_labels])

c = apply_depthwise_conv(X,kernel_size,num_channels,depth)
p = apply_max_pool(c,20,2)
c = apply_depthwise_conv(p,6,depth*num_channels,depth//10)

shape = c.get_shape().as_list()
c_flat = tf.reshape(c, [-1, shape[1] * shape[2] * shape[3]])

f_weights_l1 = weight_variable([shape[1] * shape[2] * depth * num_channels * (depth//10), num_hidden])
f_biases_l1 = bias_variable([num_hidden])
f = tf.nn.tanh(tf.add(tf.matmul(c_flat, f_weights_l1),f_biases_l1))

out_weights = weight_variable([num_hidden, num_labels])
out_biases = bias_variable([num_labels])
y_ = tf.nn.softmax(tf.matmul(f, out_weights) + out_biases)

loss = -tf.reduce_sum(Y * tf.log(y_))
optimizer = tf.train.GradientDescentOptimizer(learning_rate = learning_rate).minimize(loss)

correct_prediction = tf.equal(tf.argmax(y_,1), tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

with tf.Session() as session:
    tf.global_variables_initializer().run()
    for epoch in range(training_epochs):
        cost_history = np.empty(shape=[1],dtype=float)
        for b in range(total_batches):
            offset = (b * batch_size) % (train_yu.shape[0] - batch_size)
            batch_x = train_xt[offset:(offset + batch_size), :, :, :]
            batch_y = train_yt[offset:(offset + batch_size), :]
            _, c = session.run([optimizer, loss],feed_dict={X: batch_x, Y : batch_y})
            cost_history = np.append(cost_history,c)
        print("Epoch: ",epoch," Training Loss: ",c," Training Accuracy: ",
              session.run(accuracy, feed_dict={X: train_xt, Y: train_yt}))
        with tf.name_scope('summary'):
            tf.summary.scalar('loss', loss)
            merged = tf.summary.merge_all()
            writer = tf.summary.FileWriter('./logs', session.graph)
    
    print("Testing Accuracy:", session.run(accuracy, feed_dict={X: test_xt, Y: test_yt}))
# Out:
# Epoch:  0  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  2  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  3  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  4  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  5  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  6  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  7  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  8  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  9  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  10  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:
Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  365  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  366  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  367  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  368  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  369  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  370  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  371  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  372  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  373  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  374  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  375  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  376  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  377  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  378  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  379  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  380  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  381  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  382  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  383  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  384  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  385  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  386  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  387  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  388  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  389  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  390  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  391  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  392  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  393  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  394  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  395  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  396  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  397  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  398  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  399  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  400  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  401  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  402  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  403  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  404  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  405  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  406  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  407  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  408  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  409  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  410  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  411  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  412  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  413  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# ...
# Epoch:  1864  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1865  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1866  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1867  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1868  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1869  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1870  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1871  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1872  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1873  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1874  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1875  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1876  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1877  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1878  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1879  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1880  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1881  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1882  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1883  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1884  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1885  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1886  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1887  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1888  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1889  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1890  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1891  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1892  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1893  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1894  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1895  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1896  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1897  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1898  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1899  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1900  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1901  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1902  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1903  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1904  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1905  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1906  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1907  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1908  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1909  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1910  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1911  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1912  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1913  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1914  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1915  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1916  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1917  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1918  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1919  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1920  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1921  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1922  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1923  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1924  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1925  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1926  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1927  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1928  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1929  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1930  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1931  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1932  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1933  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1934  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1935  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1936  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1937  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1938  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1939  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1940  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1941  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1942  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1943  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1944  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1945  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1946  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1947  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1948  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1949  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1950  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1951  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1952  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1953  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1954  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1955  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1956  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1957  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1958  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1959  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1960  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1961  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1962  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1963  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1964  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1965  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1966  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1967  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1968  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1969  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1970  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1971  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1972  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1973  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1974  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1975  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1976  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1977  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1978  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1979  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1980  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1981  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1982  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1983  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1984  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1985  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1986  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1987  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1988  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1989  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1990  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1991  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1992  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1993  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1994  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1995  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1996  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1997  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1998  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Epoch:  1999  Training Loss:  Tensor("Relu_1:0", shape=(?, 1, 1, 1080), dtype=float32)  Training Accuracy:  0.777778
# Testing Accuracy: 0.933333

# %%
batch_y.shape

# %%
#standing label
input_height = 1
input_width = 90
num_labels = 10 #number of users
num_channels = 3

batch_size = 32
kernel_size = 60
depth = 60
num_hidden = 10000

learning_rate = 1e-5
training_epochs = 1000

total_batches = train_xj.shape[0] // batch_size
X = tf.placeholder(tf.float32, shape=[None,input_height,input_width,num_channels])
Y = tf.placeholder(tf.float32, shape=[None,num_labels])

c = apply_depthwise_conv(X,kernel_size,num_channels,depth)
p = apply_max_pool(c,20,2)
c = apply_depthwise_conv(p,6,depth*num_channels,depth//10)

shape = c.get_shape().as_list()
c_flat = tf.reshape(c, [-1, shape[1] * shape[2] * shape[3]])

f_weights_l1 = weight_variable([shape[1] * shape[2] * depth * num_channels * (depth//10), num_hidden])
f_biases_l1 = bias_variable([num_hidden])
f = tf.nn.tanh(tf.add(tf.matmul(c_flat, f_weights_l1),f_biases_l1))

out_weights = weight_variable([num_hidden, num_labels])
out_biases = bias_variable([num_labels])
y_ = tf.nn.softmax(tf.matmul(f, out_weights) + out_biases)

loss = -tf.reduce_sum(Y * tf.log(y_))
optimizer = tf.train.GradientDescentOptimizer(learning_rate = learning_rate).minimize(loss)

correct_prediction = tf.equal(tf.argmax(y_,1), tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

with tf.Session() as session:
    tf.global_variables_initializer().run()
    for epoch in range(training_epochs):
        cost_history = np.empty(shape=[1],dtype=float)
        for b in range(total_batches):
            offset = (b * batch_size) % (train_yj.shape[0] - batch_size)
            batch_x = train_xj[offset:(offset + batch_size), :, :, :]
            batch_y = train_yj[offset:(offset + batch_size), :]
            _, c = session.run([optimizer, loss],feed_dict={X: batch_x, Y : batch_y})
            cost_history = np.append(cost_history,c)
        print("Epoch: ",epoch," Training Loss: ",c," Training Accuracy: ",
              session.run(accuracy, feed_dict={X: train_xj, Y: train_yj}))
        with tf.name_scope('summary'):
            tf.summary.scalar('loss', loss)
            merged = tf.summary.merge_all()
            writer = tf.summary.FileWriter('./logs', session.graph)
    
    print("Testing Accuracy:", session.run(accuracy, feed_dict={X: test_xj, Y: test_yj}))

# %%
#upstairs label
input_height = 1
input_width = 90
num_labels = 10 #number of users
num_channels = 3

batch_size = 128
kernel_size = 60
depth = 60
num_hidden = 10000

learning_rate = 1e-5
training_epochs = 2000

total_batches = train_xj.shape[0] // batch_size
X = tf.placeholder(tf.float32, shape=[None,input_height,input_width,num_channels])
Y = tf.placeholder(tf.float32, shape=[None,num_labels])

c = apply_depthwise_conv(X,kernel_size,num_channels,depth)
p = apply_max_pool(c,20,2)
c = apply_depthwise_conv(p,6,depth*num_channels,depth//10)

shape = c.get_shape().as_list()
c_flat = tf.reshape(c, [-1, shape[1] * shape[2] * shape[3]])

f_weights_l1 = weight_variable([shape[1] * shape[2] * depth * num_channels * (depth//10), num_hidden])
f_biases_l1 = bias_variable([num_hidden])
f = tf.nn.tanh(tf.add(tf.matmul(c_flat, f_weights_l1),f_biases_l1))

out_weights = weight_variable([num_hidden, num_labels])
out_biases = bias_variable([num_labels])
y_ = tf.nn.softmax(tf.matmul(f, out_weights) + out_biases)

loss = -tf.reduce_sum(Y * tf.log(y_))
optimizer = tf.train.GradientDescentOptimizer(learning_rate = learning_rate).minimize(loss)

correct_prediction = tf.equal(tf.argmax(y_,1), tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

with tf.Session() as session:
    tf.global_variables_initializer().run()
    for epoch in range(training_epochs):
        cost_history = np.empty(shape=[1],dtype=float)
        for b in range(total_batches):
            offset = (b * batch_size) % (train_yj.shape[0] - batch_size)
            batch_x = train_xj[offset:(offset + batch_size), :, :, :]
            batch_y = train_yj[offset:(offset + batch_size), :]
            _, c = session.run([optimizer, loss],feed_dict={X: batch_x, Y : batch_y})
            cost_history = np.append(cost_history,c)
        print("Epoch: ",epoch," Training Loss: ",c," Training Accuracy: ",
              session.run(accuracy, feed_dict={X: train_xj, Y: train_yj}))
        with tf.name_scope('summary'):
            tf.summary.scalar('loss', loss)
            merged = tf.summary.merge_all()
            writer = tf.summary.FileWriter('./logs', session.graph)
    
    print("Testing Accuracy:", session.run(accuracy, feed_dict={X: test_xj, Y: test_yj}))
